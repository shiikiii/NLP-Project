# %%
import pandas as pd

# %%
full_data = pd.read_csv('Full+data.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
full_data.head()
# Out:
#                    product_id                brand           mpn  \
# 0  01DSRPSZTDW2PGK1YWYXJGKZZ0                 FILA  400010319073
# 1  01DSQXJBX0R7DCW7KTAC1SW547               CHANEL  400011497371
# 2  01DPGV8TGRAB993PF7Z3YWG2VR                Frame      LWBT0099
# 3  01DSR8G3F7DBRTMP8THF97XSQ2  Lilly Pulitzer Kids  400011844797
# 4  01DSR8G5GP519DEDCSKBMWQVK5          Kissy Kissy  400094474585
#
#                                                 name  \
# 0                          Original Fitness Sneakers
# 1                                                HAT
# 2                             Petit Oval Buckle Belt
# 3  Little Gir's & Girl's Ariana One-Piece UPF 50+...
# 4  Baby Girl's Endearing Elephants Pima Cotton Co...
#
#                                          description  \
# 0  Vintage Fitness leather sneakers with logo pri...
# 1                                                NaN
# 2  A Timeless Leather Belt Crafted From Smooth Co...
# ...

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42373 entries, 0 to 42372
# Columns: 256 entries, product_id to Unnamed: 255
# dtypes: float64(244), object(12)
# memory usage: 82.8+ MB
